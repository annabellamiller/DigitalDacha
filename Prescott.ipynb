# %%
import data_processing as dp

dacha_file = 'digital_dacha_data_2024.csv'
population_file = 'Population.csv'

df = dp.process_data(dacha_file, population_file)

# Prescott
Wage_Expert = 4_500
Wage_Staff = 1_160
pop_estimate = 47_757
med_inc_estimate = 66_330

recdf_Prescott = dp.calculate_recommended_staffing(df, Wage_Expert, Wage_Staff, pop_estimate, med_inc_estimate, Contribution_Margin=100, Rev=1000)

# %%
dp.calculate_net_income(recdf_Prescott)
# Out:
# 229012.13589960895

# %%
recdf_Prescott
# Out:
#     Month  RecExperts   RecStaff     Quantity       Revenue    GrossProfit  \
# 0     1.0    3.738523   9.173037   736.933750  7.369337e+05   73693.374962
# 1     2.0    4.449101  10.916548   877.002096  8.770021e+05   87700.209565
# 2     3.0    4.744407  11.641126   935.212463  9.352125e+05   93521.246317
# 3     4.0    4.654916  11.421547   917.572111  9.175721e+05   91757.211137
# 4     5.0    4.771206  11.706882   940.495080  9.404951e+05   94049.508006
# 5     6.0    4.685019  11.495410   923.506024  9.235060e+05   92350.602423
# 6     7.0    4.574958  11.225356   901.810731  9.018107e+05   90181.073119
# 7     8.0    4.673796  11.467871   921.293676  9.212937e+05   92129.367593
# 8     9.0    4.896556  12.014448   965.203951  9.652040e+05   96520.395134
# 9    10.0    5.069842  12.439630   999.361782  9.993618e+05   99936.178244
# 10   11.0    5.371632  13.180119  1058.850400  1.058850e+06  105885.040045
# 11   12.0    7.324628  17.972091  1443.822802  1.443823e+06  144382.280201
#
#         EmpWages
# 0   27464.079022
# 1   32684.152231
# 2   34853.538732
# 3   34196.117344
# 4   35050.411540
# 5   34417.262665
# 6   33608.721539
# 7   34334.812771
# 8   35971.262846
# 9   37244.258370
# 10  39461.282775
# 11  53808.451013

# %%
import matplotlib.pyplot as plt

# Define the DataFrame
df_to_use = recdf_Prescott

# Create the bar plot
plt.figure(figsize=(12, 6))
bars1 = plt.bar([m - 0.15 for m in df_to_use['Month']], df_to_use['RecExperts'], width=0.3, label='Recommended Experts', color='#cca677')
bars2 = plt.bar([m + 0.15 for m in df_to_use['Month']], df_to_use['RecStaff'], width=0.3, label='Recommended Staff', color='#77a6cc')

# Adding labels and title
plt.ylabel('Employee FTE', fontsize = 18)

# Month dictionary
month_dict = {
    1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'April', 
    5: 'May', 6: 'June', 7: 'July', 8: 'Aug', 
    9: 'Sept', 10: 'Oct', 11: 'Nov', 12: 'Dec'
}

# Convert the month numbers to month names
month_names = [month_dict[m] for m in df_to_use['Month']]

# Set the x-ticks to the month names
plt.xticks(df_to_use['Month'], month_names)

# Add the numbers on top of the bars
for bar in bars1:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height-0.1, f'{round(height)}', ha='center', va='top', fontsize=10)

for bar in bars2:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height-0.1, f'{height:.1f}', ha='center', va='top', fontsize=10)

# Show legend with updated labels
plt.legend(fontsize = 14)

# Display the plot
plt.show()

# %%
dp.calculate_net_income(recdf_Prescott)
# Out:
# 229012.13589960895
